# %%
# # Import libraries
# import pandas as pd
# import numpy as np
# from numpy import nan as NA
# import random
# from matplotlib import pyplot
# %matplotlib inline

# %%
# bodyFat = pd.read_csv("bodyfat.csv")
# bodyFat.head()

# %%
# bodyFatmissing = bodyFat.copy()
# bodyFatmissing.head()

# %%
# replaceIndices = random.sample(range(0, 252), 50)
# print(replaceIndices)
# for item in replaceIndices:
#     bodyFatMissing.loc[item, "Abdomen"] = NA
# bodyFatMissing.head()

# %%
#meanReplacememt = bodyFatMissing["Abdomen"].fillna(bodyFatMissing["Abdomen"].mean())
#print(meanReplacememt)
#medianReplacememt = bodyFatMissing["Abdomen"].fillna(bodyFatMissing["Abdomen"].median())
#print(medianReplacememt)
#bodyFat["Abdomen"].plot.hist(bins=50)
#meanReplacememt.plot.hist(bins = 50, color="pink")
#medianReplacememt.plot.hist(bins=50, color="green")

# pyplot.hist(bodyFat["Abdomen"], bins=50, alpha=0.3, label="Original",
# histtype="step", stacked=True, fill=False)
# pyplot.hist(meanReplacememt, bins=50, color="red", alpha=0.3, label="Replaced with mean",histtype="step", stacked=True, fill=False)
# pyplot.hist(medianReplacememt, bins=50, color="green", alpha=0.3,label="Replaced with Median",histtype="step", stacked=True, fill=False)
# pyplot.legend(loc="upper right")
# pyplot.xlabel("Abdomen Circumference (cm)")
# pyplot.ylabel("Frequency")
# pyplot.show()

# %%
bins=[18,25,35,45,65,100]
group_names = ["Youth", "YoungAdult", "Adult", "MiddleAged", "Senior"]
bodyFat["AgeGroups"] = pd.cut(bodyFat["Age"], bins, labels=group_names)
print(bodyFat["AgeGroups"])
# Out:
# 0           Youth
# 1           Youth
# 2           Youth
# 3      YoungAdult
# 4           Youth
#           ...
# 247        Senior
# 248        Senior
# 249        Senior
# 250        Senior
# 251        Senior
# Name: AgeGroups, Length: 252, dtype: category
# Categories (5, object): [Youth < YoungAdult < Adult < MiddleAged < Senior]

# %%
print(bodyFat.head())
# Out:
#    id  Density  bodyfat  Age  Weight  Height  Neck  Chest  Abdomen    Hip  \
# 0   1   1.0708     12.3   23  154.25   67.75  36.2   93.1     85.2   94.5
# 1   2   1.0853      6.1   22  173.25   72.25  38.5   93.6     83.0   98.7
# 2   3   1.0414     25.3   22  154.00   66.25  34.0   95.8     87.9   99.2
# 3   4   1.0751     10.4   26  184.75   72.25  37.4  101.8     86.4  101.2
# 4   5   1.0340     28.7   24  184.25   71.25  34.4   97.3    100.0  101.9
#
#    Thigh  Knee  Ankle  Biceps  Forearm  Wrist   AgeGroups
# 0   59.0  37.3   21.9    32.0     27.4   17.1       Youth
# 1   58.7  37.3   23.4    30.5     28.9   18.2       Youth
# 2   59.6  38.9   24.0    28.8     25.2   16.6       Youth
# 3   60.1  37.3   22.8    32.4     29.4   18.2  YoungAdult
# 4   63.2  42.2   24.0    32.2     27.7   17.7       Youth

# %%
# bins=[0,72,78]
# group_names = ["0","1"]
# bodyFat["Tall"] = pd.cut(bodyFat["Height"], bins, labels=group_names)
# print(bodyFat["Tall"])
# bodyFat.head()

# %%
# guitars = pd.read_csv("guitars.csv")
# guitarPayment = pd.read_csv("guitarPayment.csv")
# retailers = pd.read_csv("retailers.csv")
# retailers.head()
# mergedOne = pd.merge(guitars, guitarPayment, on='order_id', how='outer')

# mergedTwo = pd.merge(guitars, guitarPayment, on='order_id', how='inner')

# mergedThree = pd.merge(mergedTwo, retailers, how='inner')
# mergedThree.shape
# mergedThree = mergedThree.drop(columns = "Customer")
#mergedThree["model","colour"].head()

# mergedThree.groupby("brand").agg({
# "cost_per_month": "mean",
# "interest_rate_per_month": "mean",
# "colour": pd.Series.mode
# })

#mergedThree[["brand","colour"]]
# Out:
#               brand               colour
# 0          Schecter               Purple
# 1           Epihone             Sunburst
# 2           Epihone             Sunburst
# 3           Epihone             Sunburst
# 4           Epihone             Sunburst
# 5      Rickenbacker               Blonde
# 6               G&L               Yellow
# 7           Charvel                Green
# 8            Fender        Seafoam Green
# 9            Fender        Seafoam Green
# 10           Fender        Seafoam Green
# 11           Fender               Yellow
# 12           Fender               Yellow
# 13           Fender               Yellow
# 14  Paul Reed Smith                 Blue
# 15           Fender                 Blue
# 16          Jackson          Silverburst
# 17          Jackson          Silverburst
# 18  Paul Reed Smith         Black Cherry
# 19           Gibson             Teaburst
# 20           Gibson             Teaburst
# 21           Gibson               Yellow
# 22           Ibanez  Antique Brown Burst
# 23           Ibanez  Antique Brown Burst
